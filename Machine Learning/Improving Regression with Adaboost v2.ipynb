# %% [markdown]
# * Optimize a Linear Regression using AdaBoost
# * by Luis A. Urso
# * Version 2.0

# %%
import numpy as np
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression 
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
## Load the data-set and split for training and test

df_sales = pd.read_csv("IceCream Sales.csv")

train_data, test_data = train_test_split(df_sales,test_size=0.3)
train_data.head()
# Out:
#          Date  Temperature  Sales Amount
# 44  2/23/2022           17           189
# 66  3/17/2022           25           982
# 59  3/10/2022           21           555
# 26   2/5/2022           28          1408
# 38  2/17/2022           23           721

# %%
## Define the features and target(y)

y = train_data["Sales Amount"]

features = ["Temperature"]

X = train_data[features]
X_test = test_data[features]

# %%
## Define the models, fit and predict

regr_1 = LinearRegression(fit_intercept=True)

regr_2 = AdaBoostRegressor(LinearRegression(fit_intercept=True), n_estimators=100, random_state=rng)

regr_1.fit(X, y)
regr_2.fit(X, y)

y_1 = regr_1.predict(X_test)
y_2 = regr_2.predict(X_test)

# %%
## Plot the prediction models

colors = sns.color_palette("colorblind")

plt.figure()
plt.scatter(X, y, color=colors[0], label="Training samples")
plt.plot(X_test, y_1, color=colors[1], label="LinearReg", linewidth=2)
plt.plot(X_test, y_2, color=colors[2], label="Adaboost", linewidth=2)
plt.xlabel("Temperature")
plt.ylabel("Sales")
plt.title("Boosted LinearRegression with AdaBoost")
plt.legend()
plt.show()
