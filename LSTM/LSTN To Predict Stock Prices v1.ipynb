# %% [markdown]
# # LSTM To Predict Stock Prices
#
# ### by Luis A. Urso
# ### Version: 1.0
#
# #### For this script we will get the stock prices of LLY from Yahoo Finance

# %%
## Code Parameters

## Window Analysis Parameters

win_start_date = "2023-03-30" # Start Date - need to be WIN_PERIODS value ahead of the start date into the Dataset
win_finish_date = "2024-02-29" # Finish Date - need to be WIN_PERIODS value behind the finish date into the Dataset 
win_periods = 6 # The Past Analysis Windows size.

# %%
## Load the Dataset 

import pandas as pd

df = pd.read_csv('LLY.csv')

df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2023-03-13  317.239990  331.799988  317.239990  324.489990  321.796173
# 1    2023-03-14  324.049988  327.279999  321.440002  327.070007  324.354767
# 2    2023-03-15  326.000000  331.359985  324.500000  329.470001  326.734833
# 3    2023-03-16  327.640015  331.700012  325.040009  329.529999  326.794312
# 4    2023-03-17  331.500000  334.950012  328.100006  329.179993  326.447205
# ..          ...         ...         ...         ...         ...         ...
# 246  2024-03-05  785.309998  788.530029  769.280029  777.590027  777.590027
# 247  2024-03-06  784.289978  787.849976  774.000000  779.770020  779.770020
# 248  2024-03-07  771.840027  792.989990  761.119995  780.159973  780.159973
# 249  2024-03-08  780.000000  780.000000  755.000000  762.140015  762.140015
# 250  2024-03-11  752.210022  756.799988  727.619995  734.369995  734.369995
#
#       Volume
# 0    5275600
# 1    4214300
# 2    4743500
# 3    3498200
# 4    8679800
# ..       ...
# 246  3168700
# 247  2518600
# 248  3977400
# 249  4042900
# 250  3966400
#
# [251 rows x 7 columns]

# %%
## Select only required columns those are: Date and Close


df = df[['Date','Close']]

df
# Out:
#            Date       Close
# 0    2023-03-13  324.489990
# 1    2023-03-14  327.070007
# 2    2023-03-15  329.470001
# 3    2023-03-16  329.529999
# 4    2023-03-17  329.179993
# ..          ...         ...
# 246  2024-03-05  777.590027
# 247  2024-03-06  779.770020
# 248  2024-03-07  780.159973
# 249  2024-03-08  762.140015
# 250  2024-03-11  734.369995
#
# [251 rows x 2 columns]

# %%
## Function to convert Date in String Format to DateTime Format 

import datetime

def str_to_datetime(s):
    split = s.split('-')
    year, month, day = int(split[0]),int(split[1]),int(split[2])
    return datetime.datetime(year=year,month=month,day=day)

# %%
## Apply the Conversion of Data in String Formato to DateTime Format using apply function 

df['Date']=df['Date'].apply(str_to_datetime)

df['Date']
# Out:
# /var/folders/mh/my9c1zbs38sgpc0s5t9vxl480000gp/T/ipykernel_23411/365926071.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date']=df['Date'].apply(str_to_datetime)
# 0     2023-03-13
# 1     2023-03-14
# 2     2023-03-15
# 3     2023-03-16
# 4     2023-03-17
#          ...
# 246   2024-03-05
# 247   2024-03-06
# 248   2024-03-07
# 249   2024-03-08
# 250   2024-03-11
# Name: Date, Length: 251, dtype: datetime64[ns]

# %%
## Substitute the Sequential Index column by the Date as a Index 

df.index = df.pop('Date')

df
# Out:
#                  Close
# Date
# 2023-03-13  324.489990
# 2023-03-14  327.070007
# 2023-03-15  329.470001
# 2023-03-16  329.529999
# 2023-03-17  329.179993
# ...                ...
# 2024-03-05  777.590027
# 2024-03-06  779.770020
# 2024-03-07  780.159973
# 2024-03-08  762.140015
# 2024-03-11  734.369995
#
# [251 rows x 1 columns]

# %%
## Make a single plot to see the data

import matplotlib.pyplot as plt

plt.plot(df.index,df['Close'])

# %%
## Transform the DataSet into a Windowed Data Set 
## The n parameter is set to default as 3 and it represents the 3 previous period of the target date. 

import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=win_periods):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date
  
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)
    
    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]
  
  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df, 
                                win_start_date, 
                                win_finish_date, 
                                n=win_periods)
windowed_df
# Out:
#     Target Date    Target-6    Target-5    Target-4    Target-3    Target-2  \
# 0    2023-03-30  330.970001  332.640015  336.130005  334.600006  337.649994
# 1    2023-03-31  332.640015  336.130005  334.600006  337.649994  335.869995
# 2    2023-04-03  336.130005  334.600006  337.649994  335.869995  340.690002
# 3    2023-04-04  334.600006  337.649994  335.869995  340.690002  343.420013
# 4    2023-04-05  337.649994  335.869995  340.690002  343.420013  350.739990
# ..          ...         ...         ...         ...         ...         ...
# 226  2024-02-23  757.309998  757.780029  782.059998  755.659973  745.909973
# 227  2024-02-26  757.780029  782.059998  755.659973  745.909973  769.640015
# 228  2024-02-27  782.059998  755.659973  745.909973  769.640015  769.539978
# 229  2024-02-28  755.659973  745.909973  769.640015  769.539978  771.919983
# 230  2024-02-29  745.909973  769.640015  769.539978  771.919983  765.000000
#
#        Target-1      Target
# 0    335.869995  340.690002
# 1    340.690002  343.420013
# 2    343.420013  350.739990
# 3    350.739990  354.619995
# 4    354.619995  362.239990
# ..          ...         ...
# 226  769.640015  769.539978
# 227  769.539978  771.919983
# 228  771.919983  765.000000
# 229  765.000000  757.640015
# 230  757.640015  753.679993
#
# [231 rows x 8 columns]

# %%
## Function to convert the dataset to array extracting the date, X, and y 

def windowed_df_to_date_X_y(windowed_dataframe):
    df_as_np = windowed_dataframe.to_numpy()
    
    ## Extract the date
    
    dates = df_as_np[:,0]
    
    ## Extract the X values (need to reshape to use in TensorFlow)
    
    middle_matrix = df_as_np[:,1:-1]
    X = middle_matrix.reshape((len(dates),middle_matrix.shape[1],1))
    
    ## Extract the y 
    
    y = df_as_np[:,-1]
    
    
    return dates, X.astype(np.float32), y.astype(np.float32)


dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((231,), (231, 6, 1), (231,))

# %%
q_80 = int(len(dates) * .8) ## First 80% of the dataset
q_90 = int(len(dates) * .9) ## First 90% of the dataset

## Defining the trainin set 
dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

## Defining the validation set
dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]

## Defining the test set
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

## Creates the model. The in the 1st layer the 3 is the size of the windows, and 1 is the quantity of variables of the model (univariate)
## in this case is only 1 because we only want the CLOSING, but it could be included more variavbles to predict. 
## The 2nd layer is the LSTM , need to be careful to avoid large numbers due overfit issues. 
## The 3rd and 4rd are dense layers with RELU activation functions
## the 5rd and last layer is a Dense with size 1, since we are predicting a single values

model = Sequential([layers.Input((win_periods, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])


## Loss funciton - we want to minimise the error (MSE)
## Optimizer is Adam that deals better with this type of problem we want to solve. 
## Metrics - mean absolute error what workes better with MSE 

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/100
# 6/6 [==============================] - 1s 38ms/step - loss: 258738.5469 - mean_absolute_error: 502.5323 - val_loss: 375903.4375 - val_mean_absolute_error: 612.6469
# Epoch 2/100
# 6/6 [==============================] - 0s 4ms/step - loss: 258246.0156 - mean_absolute_error: 502.0443 - val_loss: 375578.4375 - val_mean_absolute_error: 612.3815
# Epoch 3/100
# 6/6 [==============================] - 0s 4ms/step - loss: 257979.3438 - mean_absolute_error: 501.7778 - val_loss: 375160.7500 - val_mean_absolute_error: 612.0405
# Epoch 4/100
# 6/6 [==============================] - 0s 4ms/step - loss: 257621.8750 - mean_absolute_error: 501.4225 - val_loss: 374713.7500 - val_mean_absolute_error: 611.6752
# Epoch 5/100
# 6/6 [==============================] - 0s 4ms/step - loss: 257218.8906 - mean_absolute_error: 501.0160 - val_loss: 374147.7500 - val_mean_absolute_error: 611.2121
# Epoch 6/100
# 6/6 [==============================] - 0s 4ms/step - loss: 256666.1562 - mean_absolute_error: 500.4674 - val_loss: 373436.0000 - val_mean_absolute_error: 610.6298
# Epoch 7/100
# 6/6 [==============================] - 0s 4ms/step - loss: 256139.3906 - mean_absolute_error: 499.9442 - val_loss: 372758.6875 - val_mean_absolute_error: 610.0749
# Epoch 8/100
# 6/6 [==============================] - 0s 4ms/step - loss: 255539.0469 - mean_absolute_error: 499.3411 - val_loss: 371949.2188 - val_mean_absolute_error: 609.4112
# Epoch 9/100
# 6/6 [==============================] - 0s 4ms/step - loss: 254813.3438 - mean_absolute_error: 498.6142 - val_loss: 370909.1250 - val_mean_absolute_error: 608.5570
# Epoch 10/100
# 6/6 [==============================] - 0s 4ms/step - loss: 253753.0625 - mean_absolute_error: 497.5477 - val_loss: 369399.6562 - val_mean_absolute_error: 607.3157
# Epoch 11/100
# 6/6 [==============================] - 0s 4ms/step - loss: 252621.5000 - mean_absolute_error: 496.4112 - val_loss: 368069.4062 - val_mean_absolute_error: 606.2194
# Epoch 12/100
# 6/6 [==============================] - 0s 4ms/step - loss: 251256.7812 - mean_absolute_error: 495.0189 - val_loss: 365987.0312 - val_mean_absolute_error: 604.4996
# Epoch 13/100
# 6/6 [==============================] - 0s 4ms/step - loss: 249633.8750 - mean_absolute_error: 493.3880 - val_loss: 364033.1562 - val_mean_absolute_error: 602.8813
# Epoch 14/100
# 6/6 [==============================] - 0s 4ms/step - loss: 247956.2188 - mean_absolute_error: 491.6899 - val_loss: 361786.8125 - val_mean_absolute_error: 601.0151
# Epoch 15/100
# 6/6 [==============================] - 0s 4ms/step - loss: 245933.2812 - mean_absolute_error: 489.6303 - val_loss: 359129.5000 - val_mean_absolute_error: 598.8006
# Epoch 16/100
# 6/6 [==============================] - 0s 4ms/step - loss: 243666.1250 - mean_absolute_error: 487.3068 - val_loss: 355992.4688 - val_mean_absolute_error: 596.1755
# Epoch 17/100
# 6/6 [==============================] - 0s 4ms/step - loss: 241054.9844 - mean_absolute_error: 484.6208 - val_loss: 352696.9375 - val_mean_absolute_error: 593.4052
# Epoch 18/100
# 6/6 [==============================] - 0s 4ms/step - loss: 238247.9531 - mean_absolute_error: 481.7175 - val_loss: 349018.0312 - val_mean_absolute_error: 590.2972
# Epoch 19/100
# 6/6 [==============================] - 0s 4ms/step - loss: 235035.6719 - mean_absolute_error: 478.3627 - val_loss: 344663.4688 - val_mean_absolute_error: 586.5971
# Epoch 20/100
# 6/6 [==============================] - 0s 4ms/step - loss: 231450.3906 - mean_absolute_error: 474.5855 - val_loss: 340070.8125 - val_mean_absolute_error: 582.6693
# Epoch 21/100
# 6/6 [==============================] - 0s 4ms/step - loss: 227368.7812 - mean_absolute_error: 470.2969 - val_loss: 334575.9375 - val_mean_absolute_error: 577.9348
# Epoch 22/100
# 6/6 [==============================] - 0s 4ms/step - loss: 222948.4062 - mean_absolute_error: 465.5594 - val_loss: 328978.9062 - val_mean_absolute_error: 573.0721
# Epoch 23/100
# 6/6 [==============================] - 0s 4ms/step - loss: 218262.2969 - mean_absolute_error: 460.5078 - val_loss: 322892.2500 - val_mean_absolute_error: 567.7367
# Epoch 24/100
# 6/6 [==============================] - 0s 4ms/step - loss: 213191.7656 - mean_absolute_error: 454.9514 - val_loss: 316165.8125 - val_mean_absolute_error: 561.7812
# Epoch 25/100
# 6/6 [==============================] - 0s 3ms/step - loss: 207406.5000 - mean_absolute_error: 448.5296 - val_loss: 308515.1875 - val_mean_absolute_error: 554.9306
# Epoch 26/100
# 6/6 [==============================] - 0s 4ms/step - loss: 201291.6094 - mean_absolute_error: 441.6761 - val_loss: 300700.8125 - val_mean_absolute_error: 547.8445
# Epoch 27/100
# 6/6 [==============================] - 0s 4ms/step - loss: 194912.7188 - mean_absolute_error: 434.3350 - val_loss: 292314.6875 - val_mean_absolute_error: 540.1364
# Epoch 28/100
# 6/6 [==============================] - 0s 4ms/step - loss: 187844.4531 - mean_absolute_error: 426.2083 - val_loss: 282648.1562 - val_mean_absolute_error: 531.1122
# Epoch 29/100
# 6/6 [==============================] - 0s 4ms/step - loss: 179465.2656 - mean_absolute_error: 416.2271 - val_loss: 271323.0938 - val_mean_absolute_error: 520.3412
# Epoch 30/100
# 6/6 [==============================] - 0s 4ms/step - loss: 170156.6250 - mean_absolute_error: 404.8446 - val_loss: 258819.6562 - val_mean_absolute_error: 508.1854
# Epoch 31/100
# 6/6 [==============================] - 0s 3ms/step - loss: 160801.0938 - mean_absolute_error: 393.0986 - val_loss: 247035.9375 - val_mean_absolute_error: 496.4561
# Epoch 32/100
# 6/6 [==============================] - 0s 4ms/step - loss: 151379.4531 - mean_absolute_error: 381.0926 - val_loss: 234849.7031 - val_mean_absolute_error: 484.0273
# Epoch 33/100
# 6/6 [==============================] - 0s 4ms/step - loss: 141915.9688 - mean_absolute_error: 368.3345 - val_loss: 222230.8750 - val_mean_absolute_error: 470.8116
# Epoch 34/100
# 6/6 [==============================] - 0s 4ms/step - loss: 132172.1094 - mean_absolute_error: 354.8604 - val_loss: 209371.3906 - val_mean_absolute_error: 456.9509
# Epoch 35/100
# 6/6 [==============================] - 0s 3ms/step - loss: 122377.4141 - mean_absolute_error: 340.7504 - val_loss: 196362.3281 - val_mean_absolute_error: 442.4873
# Epoch 36/100
# 6/6 [==============================] - 0s 3ms/step - loss: 112511.2500 - mean_absolute_error: 326.0769 - val_loss: 183293.8906 - val_mean_absolute_error: 427.4651
# Epoch 37/100
# 6/6 [==============================] - 0s 3ms/step - loss: 102351.2734 - mean_absolute_error: 310.1228 - val_loss: 168537.9844 - val_mean_absolute_error: 409.8426
# Epoch 38/100
# 6/6 [==============================] - 0s 4ms/step - loss: 91956.6641 - mean_absolute_error: 292.7962 - val_loss: 155238.8281 - val_mean_absolute_error: 393.2830
# Epoch 39/100
# 6/6 [==============================] - 0s 4ms/step - loss: 82434.9062 - mean_absolute_error: 276.0757 - val_loss: 142207.5156 - val_mean_absolute_error: 376.3511
# Epoch 40/100
# 6/6 [==============================] - 0s 4ms/step - loss: 73074.5312 - mean_absolute_error: 258.6167 - val_loss: 128472.8984 - val_mean_absolute_error: 357.6393
# Epoch 41/100
# 6/6 [==============================] - 0s 4ms/step - loss: 63856.4688 - mean_absolute_error: 239.9749 - val_loss: 115922.0312 - val_mean_absolute_error: 339.6392
# Epoch 42/100
# 6/6 [==============================] - 0s 4ms/step - loss: 55470.7383 - mean_absolute_error: 222.0105 - val_loss: 104041.4219 - val_mean_absolute_error: 321.6739
# Epoch 43/100
# 6/6 [==============================] - 0s 4ms/step - loss: 47775.3711 - mean_absolute_error: 203.8969 - val_loss: 92238.2578 - val_mean_absolute_error: 302.7684
# Epoch 44/100
# 6/6 [==============================] - 0s 4ms/step - loss: 40372.8477 - mean_absolute_error: 184.6617 - val_loss: 81252.5547 - val_mean_absolute_error: 284.0507
# Epoch 45/100
# 6/6 [==============================] - 0s 3ms/step - loss: 33534.7773 - mean_absolute_error: 164.9708 - val_loss: 69615.1016 - val_mean_absolute_error: 262.7698
# Epoch 46/100
# 6/6 [==============================] - 0s 3ms/step - loss: 27289.7500 - mean_absolute_error: 145.5130 - val_loss: 60440.2930 - val_mean_absolute_error: 244.6897
# Epoch 47/100
# 6/6 [==============================] - 0s 3ms/step - loss: 22437.4180 - mean_absolute_error: 129.1915 - val_loss: 52271.3477 - val_mean_absolute_error: 227.3853
# Epoch 48/100
# 6/6 [==============================] - 0s 4ms/step - loss: 18429.8926 - mean_absolute_error: 115.3193 - val_loss: 45133.4219 - val_mean_absolute_error: 211.1070
# Epoch 49/100
# 6/6 [==============================] - 0s 3ms/step - loss: 15172.6875 - mean_absolute_error: 103.2366 - val_loss: 39042.3867 - val_mean_absolute_error: 196.1508
# Epoch 50/100
# 6/6 [==============================] - 0s 4ms/step - loss: 12634.9033 - mean_absolute_error: 92.4690 - val_loss: 33856.5234 - val_mean_absolute_error: 182.4534
# Epoch 51/100
# 6/6 [==============================] - 0s 4ms/step - loss: 10696.2217 - mean_absolute_error: 83.5851 - val_loss: 29504.3594 - val_mean_absolute_error: 170.1091
# Epoch 52/100
# 6/6 [==============================] - 0s 3ms/step - loss: 9283.6738 - mean_absolute_error: 78.1441 - val_loss: 25873.6602 - val_mean_absolute_error: 159.0798
# Epoch 53/100
# 6/6 [==============================] - 0s 3ms/step - loss: 8203.8330 - mean_absolute_error: 75.0157 - val_loss: 22975.7383 - val_mean_absolute_error: 149.6946
# Epoch 54/100
# 6/6 [==============================] - 0s 4ms/step - loss: 7482.2842 - mean_absolute_error: 74.0116 - val_loss: 20612.2812 - val_mean_absolute_error: 141.5804
# Epoch 55/100
# 6/6 [==============================] - 0s 4ms/step - loss: 7001.1265 - mean_absolute_error: 73.7139 - val_loss: 18700.2031 - val_mean_absolute_error: 134.6586
# Epoch 56/100
# 6/6 [==============================] - 0s 3ms/step - loss: 6690.9189 - mean_absolute_error: 73.6348 - val_loss: 17179.9785 - val_mean_absolute_error: 128.8903
# Epoch 57/100
# 6/6 [==============================] - 0s 4ms/step - loss: 6468.8374 - mean_absolute_error: 73.3757 - val_loss: 16033.9160 - val_mean_absolute_error: 124.3650
# Epoch 58/100
# 6/6 [==============================] - 0s 3ms/step - loss: 6365.7432 - mean_absolute_error: 73.3496 - val_loss: 15134.3994 - val_mean_absolute_error: 120.7005
# Epoch 59/100
# 6/6 [==============================] - 0s 4ms/step - loss: 6279.7905 - mean_absolute_error: 73.1513 - val_loss: 14640.0947 - val_mean_absolute_error: 118.6362
# Epoch 60/100
# 6/6 [==============================] - 0s 3ms/step - loss: 6236.3330 - mean_absolute_error: 73.0147 - val_loss: 13937.9785 - val_mean_absolute_error: 115.6341
# Epoch 61/100
# 6/6 [==============================] - 0s 4ms/step - loss: 6207.4614 - mean_absolute_error: 72.9438 - val_loss: 13563.8574 - val_mean_absolute_error: 114.0026
# Epoch 62/100
# 6/6 [==============================] - 0s 3ms/step - loss: 6201.7764 - mean_absolute_error: 72.9306 - val_loss: 13285.4189 - val_mean_absolute_error: 112.7756
# Epoch 63/100
# 6/6 [==============================] - 0s 3ms/step - loss: 6083.0986 - mean_absolute_error: 72.2620 - val_loss: 14488.9795 - val_mean_absolute_error: 118.0471
# Epoch 64/100
# 6/6 [==============================] - 0s 5ms/step - loss: 6065.9795 - mean_absolute_error: 71.9391 - val_loss: 12911.4453 - val_mean_absolute_error: 111.1289
# Epoch 65/100
# 6/6 [==============================] - 0s 4ms/step - loss: 6004.9536 - mean_absolute_error: 71.7477 - val_loss: 13845.8340 - val_mean_absolute_error: 115.3210
# Epoch 66/100
# 6/6 [==============================] - 0s 4ms/step - loss: 5937.3486 - mean_absolute_error: 71.1556 - val_loss: 12629.3965 - val_mean_absolute_error: 109.8831
# Epoch 67/100
# 6/6 [==============================] - 0s 4ms/step - loss: 5900.9771 - mean_absolute_error: 71.2850 - val_loss: 13283.6436 - val_mean_absolute_error: 112.8807
# Epoch 68/100
# 6/6 [==============================] - 0s 3ms/step - loss: 5768.3521 - mean_absolute_error: 70.1820 - val_loss: 13089.9316 - val_mean_absolute_error: 112.0620
# Epoch 69/100
# 6/6 [==============================] - 0s 4ms/step - loss: 5657.8267 - mean_absolute_error: 69.7162 - val_loss: 12925.5938 - val_mean_absolute_error: 111.3287
# Epoch 70/100
# 6/6 [==============================] - 0s 4ms/step - loss: 5538.3833 - mean_absolute_error: 68.9090 - val_loss: 12882.7529 - val_mean_absolute_error: 111.2001
# Epoch 71/100
# 6/6 [==============================] - 0s 4ms/step - loss: 5508.1582 - mean_absolute_error: 68.1888 - val_loss: 12651.1357 - val_mean_absolute_error: 110.1695
# Epoch 72/100
# 6/6 [==============================] - 0s 4ms/step - loss: 5389.3252 - mean_absolute_error: 68.0357 - val_loss: 12642.6953 - val_mean_absolute_error: 110.1400
# Epoch 73/100
# 6/6 [==============================] - 0s 4ms/step - loss: 5176.4160 - mean_absolute_error: 66.4034 - val_loss: 12108.7090 - val_mean_absolute_error: 107.7416
# Epoch 74/100
# 6/6 [==============================] - 0s 4ms/step - loss: 5009.1270 - mean_absolute_error: 65.4218 - val_loss: 11192.2715 - val_mean_absolute_error: 103.3515
# Epoch 75/100
# 6/6 [==============================] - 0s 4ms/step - loss: 4927.9648 - mean_absolute_error: 64.7622 - val_loss: 11264.0322 - val_mean_absolute_error: 103.7810
# Epoch 76/100
# 6/6 [==============================] - 0s 4ms/step - loss: 4686.4180 - mean_absolute_error: 63.1583 - val_loss: 11516.9131 - val_mean_absolute_error: 105.1297
# Epoch 77/100
# 6/6 [==============================] - 0s 4ms/step - loss: 4294.7842 - mean_absolute_error: 60.5043 - val_loss: 11262.9746 - val_mean_absolute_error: 103.9610
# Epoch 78/100
# 6/6 [==============================] - 0s 4ms/step - loss: 4112.8247 - mean_absolute_error: 59.0512 - val_loss: 10835.5498 - val_mean_absolute_error: 101.9211
# Epoch 79/100
# 6/6 [==============================] - 0s 4ms/step - loss: 3807.5886 - mean_absolute_error: 56.8040 - val_loss: 10096.6016 - val_mean_absolute_error: 98.2565
# Epoch 80/100
# 6/6 [==============================] - 0s 4ms/step - loss: 3545.8079 - mean_absolute_error: 54.6746 - val_loss: 9738.1748 - val_mean_absolute_error: 96.4671
# Epoch 81/100
# 6/6 [==============================] - 0s 4ms/step - loss: 3242.4551 - mean_absolute_error: 51.7302 - val_loss: 9457.8955 - val_mean_absolute_error: 95.0650
# Epoch 82/100
# 6/6 [==============================] - 0s 4ms/step - loss: 2971.1973 - mean_absolute_error: 50.0776 - val_loss: 9284.6279 - val_mean_absolute_error: 94.3040
# Epoch 83/100
# 6/6 [==============================] - 0s 4ms/step - loss: 2735.0945 - mean_absolute_error: 47.1339 - val_loss: 7889.4839 - val_mean_absolute_error: 86.4499
# Epoch 84/100
# 6/6 [==============================] - 0s 3ms/step - loss: 2555.8513 - mean_absolute_error: 45.8956 - val_loss: 7399.7920 - val_mean_absolute_error: 83.5443
# Epoch 85/100
# 6/6 [==============================] - 0s 5ms/step - loss: 2372.7195 - mean_absolute_error: 45.1574 - val_loss: 8614.1553 - val_mean_absolute_error: 90.9984
# Epoch 86/100
# 6/6 [==============================] - 0s 4ms/step - loss: 2447.1382 - mean_absolute_error: 44.0440 - val_loss: 7240.5625 - val_mean_absolute_error: 82.9346
# Epoch 87/100
# 6/6 [==============================] - 0s 4ms/step - loss: 2061.0774 - mean_absolute_error: 40.5837 - val_loss: 6314.3623 - val_mean_absolute_error: 76.9972
# Epoch 88/100
# 6/6 [==============================] - 0s 4ms/step - loss: 1920.3650 - mean_absolute_error: 39.6941 - val_loss: 5875.8530 - val_mean_absolute_error: 74.1681
# Epoch 89/100
# 6/6 [==============================] - 0s 4ms/step - loss: 1714.8060 - mean_absolute_error: 37.6439 - val_loss: 5760.2100 - val_mean_absolute_error: 73.5558
# Epoch 90/100
# 6/6 [==============================] - 0s 4ms/step - loss: 1589.9664 - mean_absolute_error: 36.5111 - val_loss: 6507.5439 - val_mean_absolute_error: 78.7819
# Epoch 91/100
# 6/6 [==============================] - 0s 4ms/step - loss: 1606.4521 - mean_absolute_error: 34.9720 - val_loss: 4895.2407 - val_mean_absolute_error: 67.3688
# Epoch 92/100
# 6/6 [==============================] - 0s 4ms/step - loss: 1378.1539 - mean_absolute_error: 32.4356 - val_loss: 4221.4980 - val_mean_absolute_error: 62.0045
# Epoch 93/100
# 6/6 [==============================] - 0s 4ms/step - loss: 1319.5573 - mean_absolute_error: 32.1293 - val_loss: 4358.6646 - val_mean_absolute_error: 63.4102
# Epoch 94/100
# 6/6 [==============================] - 0s 4ms/step - loss: 1262.6805 - mean_absolute_error: 31.6737 - val_loss: 4761.7446 - val_mean_absolute_error: 66.8776
# Epoch 95/100
# 6/6 [==============================] - 0s 3ms/step - loss: 1109.1848 - mean_absolute_error: 30.1071 - val_loss: 4319.9556 - val_mean_absolute_error: 63.4690
# Epoch 96/100
# 6/6 [==============================] - 0s 4ms/step - loss: 969.1531 - mean_absolute_error: 27.0908 - val_loss: 3611.3496 - val_mean_absolute_error: 57.3491
# Epoch 97/100
# 6/6 [==============================] - 0s 4ms/step - loss: 878.6727 - mean_absolute_error: 26.0452 - val_loss: 3946.9641 - val_mean_absolute_error: 60.5757
# Epoch 98/100
# 6/6 [==============================] - 0s 4ms/step - loss: 868.4683 - mean_absolute_error: 25.4050 - val_loss: 3670.8091 - val_mean_absolute_error: 58.2069
# Epoch 99/100
# 6/6 [==============================] - 0s 3ms/step - loss: 807.7643 - mean_absolute_error: 23.8338 - val_loss: 2539.9087 - val_mean_absolute_error: 46.6894
# Epoch 100/100
# 6/6 [==============================] - 0s 3ms/step - loss: 829.9741 - mean_absolute_error: 24.0344 - val_loss: 2589.1489 - val_mean_absolute_error: 47.5205

# %%
## Compares Training Data Performance x Training Predicted Performance

train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 6/6 [==============================] - 0s 826us/step

# %%
## Compares Validation Data Performance x Validation Predicted Performance

val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 13ms/step

# %%
## Compares Test Data Performance x Test Predicted Performance

test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 12ms/step

# %%
## Makes a Graph with all Observations x Predictions 

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])

# %% [markdown]
# ### Makes a Prediction for the Future using Recursive Prediction (previous predicted values is the parameter for the next predicted value)

# %%
## Makes the Recursive Prediction

from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step

# %%
## Plot the Prediction Results 

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations',
            'Recursive Predictions'])
